# %%
from googleapiclient.discovery import build
from datetime import datetime
import csv
import time

# Your API key here
API_KEY = 'your_API_KEY'

# Channel usernames or IDs
CHANNELS = {
    'ABC News': 'UCBi2mrWuNuyYy4gbM6fU18Q',
    'CNN': 'UCupvZG-5ko_eiXAupbDfxWw',
    'Fox News': 'UCXIJgqnII2ZOINSWNOGFThA',
    'NBC News': 'UCeY0bbntWzzVIaj2z3QigXg',
    'CBS News': 'UC8p1vwvWtl6T73JiExfWs1g',
    'The Young Turks': 'UCuMo0RRtnNDuMB8DV5stEag',
    'USA Today': 'UCP6HGa63sBC7-KHtkme-p-g',
    'TMZ': 'UCVHJesse7CQkYggLKAqBpSg',
    'The Wall Street Journal': 'UCK7tptUDHh-RYDsdxO1-5QQ',
    'The New York Times': 'UCqnbDFdCpuN8CMEg0VuEBqA'
}

# %%
def get_youtube_service():
    """Initialize YouTube API service"""
    return build('youtube', 'v3', developerKey=API_KEY)

# %%
def get_channel_stats(youtube, channel_id):
    """Get channel statistics"""
    try:
        request = youtube.channels().list(
            part='statistics,snippet,contentDetails',
            id=channel_id
        )
        response = request.execute()
    except Exception as e:
        print(f"API request failed: {e}")
        return None

    items = response.get('items')
    if not items:
        return None

    channel = items[0]
    stats = channel.get('statistics', {})
    snippet = channel.get('snippet', {})

    def cast_int(val):
        try:
            return int(val)
        except (ValueError, TypeError):
            return None

    subscribers = cast_int(stats.get('subscriberCount'))
    total_views = cast_int(stats.get('viewCount'))
    total_videos = cast_int(stats.get('videoCount'))

    return {
        'channel_name': snippet.get('title', 'Unknown'),
        'subscribers': subscribers if subscribers is not None else 'Hidden',
        'total_views': total_views,
        'total_videos': total_videos,
        'published_at': snippet.get('publishedAt', None),
        'description': snippet.get('description', '')[:200]
    }

# %%
def save_channel_stats_to_csv(stats_list, filename="channel_stats.csv"):
    """
    Save a list of channel stats dictionaries to a CSV file.
    """
    if not stats_list:
        print("No data to save.")
        return

    # Get CSV column names from keys of first dictionary
    fieldnames = stats_list[0].keys()

    # Write to CSV
    with open(filename, mode="w", newline="", encoding="utf-8") as file:
        writer = csv.DictWriter(file, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(stats_list)

    print(f"Saved {len(stats_list)} records to {filename}")

# %%
# --- MAIN SCRIPT ---
if __name__ == "__main__":
    youtube = get_youtube_service()
    stats_list = []
    failed_channels = []

    for name, channel_id in CHANNELS.items():
        stats = None
        for attempt in range(3):  # retry up to 3 times
            stats = get_channel_stats(youtube, channel_id)
            if stats:
                break
            print(f"Retrying {name} ({attempt + 1}/3)...")
            time.sleep(2)

        if stats:
            stats["label"] = name  # human-friendly channel name
            stats_list.append(stats)
        else:
            print(f"Failed to fetch data for: {name}")
            failed_channels.append(name)

        time.sleep(1)  # avoid quota issues

    save_channel_stats_to_csv(stats_list, filename="news_channel_stats.csv")

    if failed_channels:
        print("Channels that could not be fetched:", failed_channels)
# Out:
# Retrying TMZ (1/3)...
# Retrying TMZ (2/3)...
# Retrying TMZ (3/3)...
# Failed to fetch data for: TMZ
# Saved 9 records to news_channel_stats.csv
# Channels that could not be fetched: ['TMZ']

# %%
def get_recent_videos(youtube, channel_id, year, month, max_results=100):
    """Get videos from a channel published in a specific month"""
    try:
        # Get uploads playlist ID
        response = youtube.channels().list(
            part='contentDetails',
            id=channel_id
        ).execute()
        items = response.get('items')
        if not items:
            return []

        uploads_playlist = items[0]['contentDetails']['relatedPlaylists']['uploads']

        videos = []
        next_page_token = None

        while len(videos) < max_results:
            playlist_response = youtube.playlistItems().list(
                part='snippet',
                playlistId=uploads_playlist,
                maxResults=min(50, max_results - len(videos)),
                pageToken=next_page_token
            ).execute()

            for item in playlist_response.get('items', []):
                video_id = item['snippet']['resourceId']['videoId']
                published_at = item['snippet']['publishedAt']
                published_dt = datetime.fromisoformat(published_at.replace('Z', '+00:00'))

                # Only include videos from the specified month/year
                if published_dt.year == year and published_dt.month == month:
                    videos.append({
                        'video_id': video_id,
                        'title': item['snippet']['title'],
                        'published_at': published_at
                    })

            next_page_token = playlist_response.get('nextPageToken')
            if not next_page_token:
                break
            time.sleep(0.1)

        # Get detailed statistics for filtered videos
        video_details = []
        for i in range(0, len(videos), 50):
            batch_ids = [v['video_id'] for v in videos[i:i+50]]
            video_response = youtube.videos().list(
                part='statistics,contentDetails,snippet',
                id=','.join(batch_ids)
            ).execute()
            for video in video_response.get('items', []):
                stats = video.get('statistics', {})
                video_details.append({
                    'video_id': video['id'],
                    'title': video['snippet']['title'],
                    'published_at': video['snippet']['publishedAt'],
                    'views': stats.get('viewCount', 0),
                    'likes': stats.get('likeCount', 0),
                    'comments': stats.get('commentCount', 0),
                    'duration': video['contentDetails']['duration']
                })

        return video_details

    except Exception as e:
        print(f"Error fetching videos for channel {channel_id}: {e}")
        return []

# %%
def scrape_all_channels(year, month):
    """Scrape videos for all channels in a specific month"""
    youtube = get_youtube_service()
    all_data = []

    for channel_name, channel_id in CHANNELS.items():
        print(f"Scraping {channel_name}...")
        stats = get_channel_stats(youtube, channel_id)
        videos = get_recent_videos(youtube, channel_id, year, month)
        print(f"  Retrieved {len(videos)} videos for {year}-{month:02d}")
        all_data.append({
            'channel': channel_name,
            'stats': stats,
            'videos': videos
        })
        time.sleep(1)

    return all_data

# %%
def save_videos_to_csv(data, filename='october_videos.csv'):
    """Save video data to CSV"""
    with open(filename, 'w', newline='', encoding='utf-8') as f:
        writer = csv.writer(f)
        writer.writerow(['Channel', 'Video ID', 'Title', 'Published', 'Views', 'Likes', 'Comments', 'Duration'])
        for channel_data in data:
            channel = channel_data['channel']
            for video in channel_data['videos']:
                writer.writerow([
                    channel,
                    video['video_id'],
                    video['title'],
                    video['published_at'],
                    video['views'],
                    video['likes'],
                    video['comments'],
                    video['duration']
                ])
    print(f"Data saved to {filename}")

# %%
# --- MAIN ---
if __name__ == '__main__':
    YEAR = 2025
    MONTH = 10  # October
    data = scrape_all_channels(YEAR, MONTH)
    save_videos_to_csv(data)
# Out:
# Scraping ABC News...
#   Retrieved 100 videos for 2025-10
# Scraping CNN...
#   Retrieved 100 videos for 2025-10
# Scraping Fox News...
#   Retrieved 100 videos for 2025-10
# Scraping NBC News...
#   Retrieved 100 videos for 2025-10
# Scraping CBS News...
#   Retrieved 100 videos for 2025-10
# Scraping The Young Turks...
#   Retrieved 100 videos for 2025-10
# Scraping USA Today...
#   Retrieved 100 videos for 2025-10
# Scraping TMZ...
#   Retrieved 0 videos for 2025-10
# Scraping The Wall Street Journal...
#   Retrieved 37 videos for 2025-10
# Scraping The New York Times...
#   Retrieved 81 videos for 2025-10
# Data saved to october_videos.csv

# %%
YOUTUBE_SERVICE = build('youtube', 'v3', developerKey=API_KEY)

# %%
def get_video_comments(video_id):
    """Fetch all comments (including replies) for a single video."""
    comments = []
    next_page_token = None

    while True:
        try:
            response = YOUTUBE_SERVICE.commentThreads().list(
                part='snippet,replies',
                videoId=video_id,
                maxResults=100,
                pageToken=next_page_token,
                textFormat='plainText'
            ).execute()
        except Exception as e:
            print(f"Error fetching comments for video {video_id}: {e}")
            break

        for item in response.get('items', []):
            top_comment = item['snippet']['topLevelComment']['snippet']
            comments.append({
                'video_id': video_id,
                'comment_id': item['snippet']['topLevelComment']['id'],
                'author': top_comment.get('authorDisplayName'),
                'text': top_comment.get('textDisplay'),
                'published_at': top_comment.get('publishedAt'),
                'like_count': top_comment.get('likeCount', 0)
            })

            # Include replies if any
            replies = item.get('replies', {}).get('comments', [])
            for reply in replies:
                reply_snippet = reply['snippet']
                comments.append({
                    'video_id': video_id,
                    'comment_id': reply['id'],
                    'author': reply_snippet.get('authorDisplayName'),
                    'text': reply_snippet.get('textDisplay'),
                    'published_at': reply_snippet.get('publishedAt'),
                    'like_count': reply_snippet.get('likeCount', 0)
                })

        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break
        time.sleep(0.1)  # avoid hitting quota limits

    return comments

# %%
def scrape_comments_from_csv(input_csv='october_videos.csv'):
    """Scrape comments for all video IDs listed in a CSV."""
    video_ids = []
    with open(input_csv, 'r', encoding='utf-8') as f:
        reader = csv.DictReader(f)
        for row in reader:
            video_ids.append(row['Video ID'])

    all_comments = []
    for vid in video_ids:
        print(f"Fetching comments for video {vid}...")
        comments = get_video_comments(vid)
        all_comments.extend(comments)
        print(f"  Retrieved {len(comments)} comments.")
        time.sleep(0.5)  # small delay between videos

    return all_comments

# %%
def save_comments_to_csv(comments, output_csv='october_video_comments.csv'):
    """Save comments to CSV."""
    with open(output_csv, 'w', newline='', encoding='utf-8') as f:
        writer = csv.DictWriter(f, fieldnames=['video_id', 'comment_id', 'author', 'text', 'published_at', 'like_count'])
        writer.writeheader()
        writer.writerows(comments)
    print(f"Saved {len(comments)} comments to {output_csv}")

# %%
# --- MAIN ---
if __name__ == '__main__':
    comments_data = scrape_comments_from_csv('october_videos.csv')
    save_comments_to_csv(comments_data, 'october_video_comments.csv')
# Out:
# Fetching comments for video QWhBHJfVaN0...
#   Retrieved 204 comments.
# Fetching comments for video pHIbuFQapLc...
#   Retrieved 7 comments.
# Fetching comments for video fOU8qXMoUaw...
#   Retrieved 152 comments.
# Fetching comments for video LnxWSjNeC4s...
#   Retrieved 254 comments.
# Fetching comments for video NbwWV1yA--E...
#   Retrieved 1413 comments.
# Fetching comments for video Ha8TU_W4UAI...
#   Retrieved 58 comments.
# Fetching comments for video zXhpJnR5_3k...
#   Retrieved 1524 comments.
# Fetching comments for video xl1-2aqghsE...
#   Retrieved 63 comments.
# Fetching comments for video UqPaVXMUFyY...
#   Retrieved 963 comments.
# Fetching comments for video iV-YUVl_xUU...
#   Retrieved 3 comments.
# Fetching comments for video n6soopF2Cs8...
#   Retrieved 41 comments.
# Fetching comments for video qyfZfot-SD8...
#   Retrieved 20 comments.
# Fetching comments for video NUwTyWGNWeU...
#   Retrieved 17 comments.
# Fetching comments for video kSTpOWMC10I...
#   Retrieved 66 comments.
# Fetching comments for video 29tcTJfzgU4...
#   Retrieved 167 comments.
# Fetching comments for video eClPv6uKkww...
#   Retrieved 26 comments.
# Fetching comments for video k3RN9WXaKKU...
#   Retrieved 292 comments.
# Fetching comments for video AbccY2aCC54...
#   Retrieved 13 comments.
# Fetching comments for video g_A9SlhfWd8...
#   Retrieved 18 comments.
# Fetching comments for video mziL2cEXfjA...
#   Retrieved 34 comments.
# Fetching comments for video j4chhx_9y9g...
#   Retrieved 39 comments.
# Fetching comments for video XBUShwrjEpE...
#   Retrieved 2 comments.
# Fetching comments for video A85aLYBT3JA...
#   Retrieved 3627 comments.
# Fetching comments for video L2KJ67kXN4g...
#   Retrieved 43 comments.
# Fetching comments for video -jBlc9bhTTQ...
#   Retrieved 410 comments.
# Fetching comments for video i24axc6w7KU...
#   Retrieved 824 comments.
# Fetching comments for video aaz4C4ywBJ4...
#   Retrieved 56 comments.
# Fetching comments for video odoXVj-Wk2U...
#   Retrieved 2 comments.
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"
# Fetching comments for video wDoHzU7yFec...
# Error fetching comments for video wDoHzU7yFec: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=wDoHzU7yFec&maxResults=100&textFormat=plainText&key=AIzaSyDJhhiLeaDbxO8vQnWR6ROtMw8jrbvzDRo&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
#   Retrieved 0 comments.
# Fetching comments for video ZSYhdiN5iRc...
#   Retrieved 198 comments.
# Fetching comments for video xYIGBs1FSdE...
#   Retrieved 825 comments.
# Fetching comments for video co7Oh0hHIkw...
#   Retrieved 175 comments.
# Fetching comments for video VmvG8V8g6lU...
#   Retrieved 163 comments.
# Fetching comments for video LkV16GTozxI...
#   Retrieved 1603 comments.
# Fetching comments for video gYYw_LTPRjk...
#   Retrieved 137 comments.
# Fetching comments for video _TNHtPwQoJs...
#   Retrieved 11 comments.
# Fetching comments for video 99PNkFDiTpw...
#   Retrieved 30 comments.
# Fetching comments for video bMDuSm9bROc...
#   Retrieved 60 comments.
# Fetching comments for video FWoqcx-eRfQ...
#   Retrieved 36 comments.
# Fetching comments for video IvV-P7YqwcA...
#   Retrieved 4 comments.
# Fetching comments for video 2pCp8uF5kSM...
#   Retrieved 186 comments.
# Fetching comments for video m3e_1ft13Yg...
#   Retrieved 195 comments.
# Fetching comments for video i-ONpZY0axY...
#   Retrieved 4 comments.
# Fetching comments for video T3d-4k7z60c...
#   Retrieved 15 comments.
# Fetching comments for video 6DXwIsTEz0c...
#   Retrieved 25 comments.
# Fetching comments for video K6GXgLaXEdI...
#   Retrieved 534 comments.
# Fetching comments for video jHAiliLYAvw...
#   Retrieved 31 comments.
# Fetching comments for video E-oQFUk2Xbg...
#   Retrieved 159 comments.
# Fetching comments for video kbQzzx6UBrQ...
#   Retrieved 73 comments.
# Fetching comments for video gnYX1eikn_0...
#   Retrieved 226 comments.
# Fetching comments for video FvYiuf8IdnI...
#   Retrieved 70 comments.
# Fetching comments for video p1aBRwr3bWU...
#   Retrieved 103 comments.
# Fetching comments for video vFARRwwngrM...
#   Retrieved 32 comments.
# Fetching comments for video Ftx0AEEWVzc...
#   Retrieved 3 comments.
# Fetching comments for video X1T2NOw5-94...
#   Retrieved 30 comments.
# Fetching comments for video H_juESofBZY...
#   Retrieved 36 comments.
# Fetching comments for video x6DEjxjqMG4...
#   Retrieved 84 comments.
# Fetching comments for video VUd8c-Npj8k...
#   Retrieved 163 comments.
# Fetching comments for video rn73_QHQtHc...
#   Retrieved 70 comments.
# Fetching comments for video 8p78oxIhiCs...
#   Retrieved 41 comments.
# Fetching comments for video ugpfgbDo-Ew...
#   Retrieved 3 comments.
# Fetching comments for video _-PwI9a5aHc...
#   Retrieved 271 comments.
# Fetching comments for video tkp_WGe0ed8...
#   Retrieved 4 comments.
# Fetching comments for video cOhwN51tJ3c...
#   Retrieved 61 comments.
# Fetching comments for video kOxN4ubAFvI...
#   Retrieved 339 comments.
# Fetching comments for video pns2Z_vNK-s...
#   Retrieved 5 comments.
# Fetching comments for video NTFHO4Vf73U...
#   Retrieved 1 comments.
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"
# Fetching comments for video 9NbD9pPxzY0...
# Error fetching comments for video 9NbD9pPxzY0: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=9NbD9pPxzY0&maxResults=100&textFormat=plainText&key=AIzaSyDJhhiLeaDbxO8vQnWR6ROtMw8jrbvzDRo&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
#   Retrieved 0 comments.
# Fetching comments for video E9_vEi24o4M...
#   Retrieved 50 comments.
# Fetching comments for video vf1P-ksBW44...
#   Retrieved 66 comments.
# Fetching comments for video cnSpNpMjEuU...
#   Retrieved 5 comments.
# Fetching comments for video r5dro2vSjHw...
#   Retrieved 3 comments.
# Fetching comments for video enfYZNyoUtk...
#   Retrieved 366 comments.
# Fetching comments for video T5NwojRjbas...
#   Retrieved 1200 comments.
# Fetching comments for video lWB0lsSPaAM...
#   Retrieved 1083 comments.
# Fetching comments for video CyP8TuemRiY...
#   Retrieved 77 comments.
# Fetching comments for video 6vlfo9LsAn0...
#   Retrieved 95 comments.
# Fetching comments for video Ub4qdtK2eC4...
#   Retrieved 244 comments.
# Fetching comments for video 6LwI981O1gw...
#   Retrieved 137 comments.
# Fetching comments for video v2STExo8_nA...
#   Retrieved 278 comments.
# Fetching comments for video ivrt8Q-JGSY...
#   Retrieved 43 comments.
# Fetching comments for video bGsr3IY1KtM...
#   Retrieved 621 comments.
# Fetching comments for video f4bk0Yk8TM8...
#   Retrieved 593 comments.
# Fetching comments for video 2AmoJwxqZYY...
#   Retrieved 41 comments.
# Fetching comments for video _EwkqSE9c3Y...
#   Retrieved 51 comments.
# Fetching comments for video pSpM7yHMwlc...
#   Retrieved 1343 comments.
# Fetching comments for video D1F9Q5eMpOk...
#   Retrieved 106 comments.
# Fetching comments for video XI31zl68YTE...
#   Retrieved 33 comments.
# Fetching comments for video N0FW6R-DhYg...
#   Retrieved 69 comments.
# Fetching comments for video RnatsevfQJ8...
#   Retrieved 290 comments.
# Fetching comments for video dBlePin4Js0...
#   Retrieved 16 comments.
# Fetching comments for video 9c41qDOFnPg...
#   Retrieved 9 comments.
# Fetching comments for video nAuaWL_b4_I...
#   Retrieved 416 comments.
# Fetching comments for video jqoJLJvm8-U...
#   Retrieved 62 comments.
# Fetching comments for video Dx5V5cZKKps...
#   Retrieved 64 comments.
# Fetching comments for video FD5Dz6rbu78...
#   Retrieved 14 comments.
# Fetching comments for video R9bvJShSCBs...
#   Retrieved 23 comments.
# Fetching comments for video hhdl0GyIKXg...
#   Retrieved 35 comments.
# Fetching comments for video K2IT034uBhM...
#   Retrieved 176 comments.
# Fetching comments for video YQHnYpupr20...
#   Retrieved 97 comments.
# Fetching comments for video F5UdJ6z7P2k...
#   Retrieved 2141 comments.
# Fetching comments for video oTv9A1iizYE...
#   Retrieved 64 comments.
# Fetching comments for video 20JpcjkQdHE...
#   Retrieved 29 comments.
# Fetching comments for video JD5qtj-xIkc...
#   Retrieved 893 comments.
# Fetching comments for video g4vB3ti39xs...
#   Retrieved 772 comments.
# Fetching comments for video xi4GGpw2OFE...
#   Retrieved 454 comments.
# Fetching comments for video o0Fl0ryZZk0...
#   Retrieved 59 comments.
# Fetching comments for video o6zPntZgqw4...
#   Retrieved 689 comments.
# Fetching comments for video fioXsmY9se0...
#   Retrieved 45 comments.
# Fetching comments for video p12Jb_WBgtk...
#   Retrieved 805 comments.
# Fetching comments for video 4lphs3GWjWQ...
#   Retrieved 58 comments.
# Fetching comments for video AGdkQWpunG0...
#   Retrieved 1222 comments.
# Fetching comments for video 5YH8Nr6XrWU...
#   Retrieved 247 comments.
# Fetching comments for video iTxvGJYwFFM...
#   Retrieved 97 comments.
# Fetching comments for video LxXUwo158rg...
#   Retrieved 11 comments.
# Fetching comments for video ST1HCjb9Y-c...
#   Retrieved 523 comments.
# Fetching comments for video BGiuYV0DUq0...
#   Retrieved 2704 comments.
# Fetching comments for video HVOd4mt4hss...
#   Retrieved 50 comments.
# Fetching comments for video 8UAJDF03PJ0...
#   Retrieved 2404 comments.
# Fetching comments for video qM33vcTEFbA...
#   Retrieved 46 comments.
# Fetching comments for video EnYFg3u3IK8...
#   Retrieved 241 comments.
# Fetching comments for video H1Gz3rP3LLI...
#   Retrieved 1483 comments.
# Fetching comments for video cFIyqAQISnI...
#   Retrieved 188 comments.
# Fetching comments for video 3_gl4n34Xt4...
#   Retrieved 1549 comments.
# Fetching comments for video AdPgEETaXD8...
#   Retrieved 384 comments.
# Fetching comments for video rWbUCKJ9JKM...
#   Retrieved 79 comments.
# Fetching comments for video mpi_9J5YLC0...
#   Retrieved 309 comments.
# Fetching comments for video YhL60EnRsJU...
#   Retrieved 88 comments.
# Fetching comments for video Q2eRdUEUZsQ...
#   Retrieved 274 comments.
# Fetching comments for video iEzsov4MdKo...
#   Retrieved 1589 comments.
# Fetching comments for video s8RchjMWvh0...
#   Retrieved 147 comments.
# Fetching comments for video 5rOxK6ru7Hg...
#   Retrieved 797 comments.
# Fetching comments for video WR8DsL0OvSU...
#   Retrieved 162 comments.
# Fetching comments for video VIP8xnJlgqI...
#   Retrieved 28 comments.
# Fetching comments for video 9gNqBbYwqr0...
#   Retrieved 67 comments.
# Fetching comments for video ksLSig37KV8...
#   Retrieved 241 comments.
# Fetching comments for video SEDAgCEUWSQ...
#   Retrieved 489 comments.
# Fetching comments for video Kbpn_XCZg24...
#   Retrieved 24 comments.
# Fetching comments for video 9n2MxrIG3k4...
#   Retrieved 979 comments.
# Fetching comments for video fQizraA8tFw...
#   Retrieved 1133 comments.
# Fetching comments for video cEeBKwDcEUE...
#   Retrieved 63 comments.
# Fetching comments for video NDng_X1_l0w...
#   Retrieved 673 comments.
# Fetching comments for video QUdR5XtgUFs...
#   Retrieved 192 comments.
# Fetching comments for video kDmWMtEq11A...
#   Retrieved 476 comments.
# Fetching comments for video 2Su4lJi3y10...
#   Retrieved 171 comments.
# Fetching comments for video fz2t3qMMcvU...
#   Retrieved 652 comments.
# Fetching comments for video jWAXWHY-wZE...
#   Retrieved 1323 comments.
# Fetching comments for video a0Oz9rEziSo...
#   Retrieved 339 comments.
# Fetching comments for video y9KfBTFbOcc...
#   Retrieved 19 comments.
# Fetching comments for video CyKQy53vA-A...
#   Retrieved 504 comments.
# Fetching comments for video _ZIXxbJjO2k...
#   Retrieved 151 comments.
# Fetching comments for video jP2zvEji3_4...
#   Retrieved 942 comments.
# Fetching comments for video K7dfatdoQnM...
#   Retrieved 46 comments.
# Fetching comments for video riOSjxcshVk...
#   Retrieved 161 comments.
# Fetching comments for video CL3hR_tC68Y...
#   Retrieved 260 comments.
# Fetching comments for video Aovv0oFv-qc...
#   Retrieved 760 comments.
# Fetching comments for video RGFnZ5_lJG0...
#   Retrieved 1242 comments.
# Fetching comments for video 9PI84uBjSEI...
#   Retrieved 938 comments.
# Fetching comments for video NdDtwqR8yfQ...
#   Retrieved 2306 comments.
# Fetching comments for video Rpi9QDpuj4Y...
#   Retrieved 63 comments.
# Fetching comments for video lB6o5Knlo0o...
#   Retrieved 384 comments.
# Fetching comments for video BEe0_bVU1u4...
#   Retrieved 68 comments.
# Fetching comments for video p1kHbU4CnRk...
#   Retrieved 115 comments.
# Fetching comments for video zVQQSptDKTc...
#   Retrieved 244 comments.
# Fetching comments for video VNgxrGZ38sI...
#   Retrieved 21 comments.
# Fetching comments for video 3MOvghdAA70...
#   Retrieved 187 comments.
# Fetching comments for video AXgt0AI7ZSk...
#   Retrieved 191 comments.
# Fetching comments for video DPixCH01AoQ...
#   Retrieved 494 comments.
# Fetching comments for video bMh4_moZGjw...
#   Retrieved 173 comments.
# Fetching comments for video 7EkA7FuxXtc...
#   Retrieved 304 comments.
# Fetching comments for video fNxxh_QSkk4...
#   Retrieved 311 comments.
# Fetching comments for video YWbNjQllfH4...
#   Retrieved 815 comments.
# Fetching comments for video r8zcZofAWIA...
#   Retrieved 84 comments.
# Fetching comments for video Xhg90q8hgJ0...
#   Retrieved 210 comments.
# Fetching comments for video l7KFKCzCeuo...
#   Retrieved 101 comments.
# Fetching comments for video irCjjt-L88o...
#   Retrieved 121 comments.
# Fetching comments for video ccpRvibE1pc...
#   Retrieved 237 comments.
# Fetching comments for video 5n277vOwfEw...
#   Retrieved 1669 comments.
# Fetching comments for video YDLeXzyGGZ8...
#   Retrieved 362 comments.
# Fetching comments for video 9c_3ohKbgCk...
#   Retrieved 223 comments.
# Fetching comments for video mt1caFWxeSY...
#   Retrieved 293 comments.
# Fetching comments for video Tl4KGtcObYU...
#   Retrieved 14 comments.
# Fetching comments for video Xy9U4ks8s54...
#   Retrieved 240 comments.
# Fetching comments for video A66wNc2kar8...
#   Retrieved 122 comments.
# Fetching comments for video q09JJTCLFak...
#   Retrieved 873 comments.
# Fetching comments for video qWdP8VifO9c...
#   Retrieved 135 comments.
# Fetching comments for video 8fNXPMCWjXU...
#   Retrieved 183 comments.
# Fetching comments for video Ca2lXzEZ-fE...
#   Retrieved 253 comments.
# Fetching comments for video 7OxqJfGuGFs...
#   Retrieved 280 comments.
# Fetching comments for video S0yCmq5Q7Dw...
#   Retrieved 7 comments.
# Fetching comments for video bS2Jo8m9kz0...
#   Retrieved 60 comments.
# Fetching comments for video ZlLRbBLG5s4...
#   Retrieved 256 comments.
# Fetching comments for video vQdl2leJLX8...
#   Retrieved 602 comments.
# Fetching comments for video S9Dmvd7nCeA...
#   Retrieved 1376 comments.
# Fetching comments for video de2ArDJTy08...
#   Retrieved 199 comments.
# Fetching comments for video Kw-TsR7D6NY...
#   Retrieved 81 comments.
# Fetching comments for video 69ZqK1xIMh0...
#   Retrieved 599 comments.
# Fetching comments for video E4Yxf_0MuFg...
#   Retrieved 21 comments.
# Fetching comments for video gHKZyaubPt8...
#   Retrieved 993 comments.
# Fetching comments for video RlsJK5Ciybs...
#   Retrieved 312 comments.
# Fetching comments for video 2rSh-RYdYT8...
#   Retrieved 139 comments.
# Fetching comments for video fGNY74caKRU...
#   Retrieved 95 comments.
# Fetching comments for video NVpH8eTRIKs...
#   Retrieved 1300 comments.
# Fetching comments for video IohDP2Ov-ts...
#   Retrieved 19 comments.
# Fetching comments for video g70mFCUfqJ8...
#   Retrieved 84 comments.
# Fetching comments for video X1ann6MS6G8...
#   Retrieved 1104 comments.
# Fetching comments for video zGkQDFZ9KGw...
#   Retrieved 186 comments.
# Fetching comments for video lPc876hjILs...
#   Retrieved 53 comments.
# Fetching comments for video Qdeyz71aiZE...
#   Retrieved 1098 comments.
# Fetching comments for video Ei0K8DAFeeo...
#   Retrieved 248 comments.
# Fetching comments for video Jj1bospnQPc...
#   Retrieved 460 comments.
# Fetching comments for video PFnJnFEy44w...
#   Retrieved 68 comments.
# Fetching comments for video w7oIewBrGCY...
#   Retrieved 104 comments.
# Fetching comments for video _-uCD7MWnLg...
#   Retrieved 1562 comments.
# Fetching comments for video Upv21UlqUos...
#   Retrieved 199 comments.
# Fetching comments for video aSXXT3Gye-I...
#   Retrieved 1045 comments.
# Fetching comments for video t0IBEt_r_gc...
#   Retrieved 232 comments.
# Fetching comments for video l7QKAgI4UT0...
#   Retrieved 1000 comments.
# Fetching comments for video 7Aga0kBvL2w...
#   Retrieved 150 comments.
# Fetching comments for video k-o8jppypwc...
#   Retrieved 973 comments.
# Fetching comments for video LNBzCDbI_aE...
#   Retrieved 160 comments.
# Fetching comments for video narl7mrJWrc...
#   Retrieved 57 comments.
# Fetching comments for video 4RaKFzOoYv4...
#   Retrieved 835 comments.
# Fetching comments for video a3SibBhcvIU...
#   Retrieved 21 comments.
# Fetching comments for video GO-dG-Kz-WE...
#   Retrieved 220 comments.
# Fetching comments for video w91fdwJFMIM...
#   Retrieved 473 comments.
# Fetching comments for video rFExNxjBzzI...
#   Retrieved 1738 comments.
# Fetching comments for video adWIi_Cl5w4...
#   Retrieved 504 comments.
# Fetching comments for video M5o7TKIi7RQ...
#   Retrieved 1750 comments.
# Fetching comments for video oTISJFARD40...
#   Retrieved 492 comments.
# Fetching comments for video fVnsJV2pn1g...
#   Retrieved 925 comments.
# Fetching comments for video unJm0TNW2aI...
#   Retrieved 85 comments.
# Fetching comments for video Sr-dygYzDjg...
#   Retrieved 406 comments.
# Fetching comments for video tzNA-wHG82k...
#   Retrieved 3231 comments.
# Fetching comments for video O4_nFbihPNU...
#   Retrieved 94 comments.
# Fetching comments for video rHJLy69GkW8...
#   Retrieved 3333 comments.
# Fetching comments for video dPAvw_ML32w...
#   Retrieved 767 comments.
# Fetching comments for video wUSlYv472R4...
#   Retrieved 1107 comments.
# Fetching comments for video oYyiUC_nAkg...
#   Retrieved 529 comments.
# Fetching comments for video ziy8OQw9YK8...
#   Retrieved 637 comments.
# Fetching comments for video bMUyEwy8zIw...
#   Retrieved 331 comments.
# Fetching comments for video VUJsaSXBi5o...
#   Retrieved 1927 comments.
# Fetching comments for video YDloGzE8zDU...
#   Retrieved 262 comments.
# Fetching comments for video SP7QEwhpVEE...
#   Retrieved 262 comments.
# Fetching comments for video Z2APADueLEY...
#   Retrieved 1147 comments.
# Fetching comments for video dn_EAneGXU4...
#   Retrieved 428 comments.
# Fetching comments for video h_6VwChC-rc...
#   Retrieved 702 comments.
# Fetching comments for video 8GNq7a_Y-_s...
#   Retrieved 52 comments.
# Fetching comments for video W5CYp_MFMZQ...
#   Retrieved 58 comments.
# Fetching comments for video aJH6aaRXni8...
#   Retrieved 529 comments.
# Fetching comments for video EQbECJUx_Gg...
#   Retrieved 90 comments.
# Fetching comments for video wOPX051mTZ0...
#   Retrieved 2606 comments.
# Fetching comments for video tUfw6M4M2_w...
#   Retrieved 100 comments.
# Fetching comments for video vPHnLDFEqDk...
#   Retrieved 2691 comments.
# Fetching comments for video HBk1ikJGuc4...
#   Retrieved 29 comments.
# Fetching comments for video UZIvQDRDMok...
#   Retrieved 421 comments.
# Fetching comments for video VrCiSTt2v-M...
#   Retrieved 700 comments.
# Fetching comments for video CAS7Nf6erWE...
#   Retrieved 50 comments.
# Fetching comments for video 3gKyWBb44hU...
#   Retrieved 836 comments.
# Fetching comments for video xU58RMzMQ44...
#   Retrieved 1892 comments.
# Fetching comments for video LOUE9F9nf10...
#   Retrieved 179 comments.
# Fetching comments for video 6DZCb8EIPI0...
#   Retrieved 152 comments.
# Fetching comments for video aVtOdb7v_tw...
#   Retrieved 240 comments.
# Fetching comments for video QKyh8LkfWYY...
#   Retrieved 2569 comments.
# Fetching comments for video E0_WCKB5Bk8...
#   Retrieved 645 comments.
# Fetching comments for video VFVjC1sz4mA...
#   Retrieved 137 comments.
# Fetching comments for video Ndi1BnGERrs...
#   Retrieved 1434 comments.
# Fetching comments for video ZFsRJUFqp-4...
#   Retrieved 88 comments.
# Fetching comments for video N6rYwLUgzkI...
#   Retrieved 84 comments.
# Fetching comments for video J_EGqp8b7tY...
#   Retrieved 592 comments.
# Fetching comments for video -bjPPxT0IPM...
#   Retrieved 359 comments.
# Fetching comments for video Xhk80wTcbeI...
#   Retrieved 176 comments.
# Fetching comments for video gqmN5ocDGfQ...
#   Retrieved 1222 comments.
# Fetching comments for video 6C_IT4taHkY...
#   Retrieved 254 comments.
# Fetching comments for video lKReGFLwFdA...
#   Retrieved 725 comments.
# Fetching comments for video m7zHUsvGBf8...
#   Retrieved 2858 comments.
# Fetching comments for video -n4qjVIsIGE...
#   Retrieved 14 comments.
# Fetching comments for video c5mYtSN-LS8...
#   Retrieved 359 comments.
# Fetching comments for video mtsRpMxY3hE...
#   Retrieved 516 comments.
# Fetching comments for video EjW8_MNGxww...
#   Retrieved 1228 comments.
# Fetching comments for video YDsQb8FlkaQ...
#   Retrieved 138 comments.
# Fetching comments for video aYwqSBcDKtg...
#   Retrieved 116 comments.
# Fetching comments for video dDR26ifxHgk...
#   Retrieved 531 comments.
# Fetching comments for video zJz1hZmWApQ...
#   Retrieved 87 comments.
# Fetching comments for video LgE-FdxxySM...
#   Retrieved 244 comments.
# Fetching comments for video 7p5wLFa4esY...
#   Retrieved 909 comments.
# Fetching comments for video dWffMvaeTR8...
#   Retrieved 33 comments.
# Fetching comments for video 1NTCsnbqels...
#   Retrieved 379 comments.
# Fetching comments for video LW-pvY5KaWI...
#   Retrieved 1418 comments.
# Fetching comments for video rqLjOukC65Y...
#   Retrieved 124 comments.
# Fetching comments for video Y5srdKD3Nh0...
#   Retrieved 600 comments.
# Fetching comments for video CPI6c0ZPzaY...
#   Retrieved 1605 comments.
# Fetching comments for video ycCCREXM8mY...
#   Retrieved 113 comments.
# Fetching comments for video ZAXJGBLwsgg...
#   Retrieved 1037 comments.
# Fetching comments for video PmFdi0ACwjY...
#   Retrieved 438 comments.
# Fetching comments for video fngh17UE5bk...
#   Retrieved 81 comments.
# Fetching comments for video PKWZ8mj55QA...
#   Retrieved 405 comments.
# Fetching comments for video -EzZ2Db1hds...
#   Retrieved 603 comments.
# Fetching comments for video r-0P5NlS7As...
#   Retrieved 129 comments.
# Fetching comments for video hRHRtOY_1zE...
#   Retrieved 620 comments.
# Fetching comments for video VPn5oSlwrGk...
#   Retrieved 26 comments.
# Fetching comments for video h6KWbc4rCcE...
#   Retrieved 1050 comments.
# Fetching comments for video 5Yt_Vb2A0uI...
#   Retrieved 4 comments.
# Fetching comments for video EqSv_6YGvD4...
#   Retrieved 20 comments.
# Fetching comments for video hM6dnqoQjt4...
#   Retrieved 5 comments.
# Fetching comments for video Ciizcx9ctSY...
#   Retrieved 98 comments.
# Fetching comments for video WoWiXL2qyDA...
#   Retrieved 163 comments.
# Fetching comments for video wIipFeqNKjw...
#   Retrieved 75 comments.
# Fetching comments for video 6oZ99Hk7_lY...
#   Retrieved 22 comments.
# Fetching comments for video iNcG8AAWUYs...
#   Retrieved 151 comments.
# Fetching comments for video r7kmvkCOh4U...
#   Retrieved 12 comments.
# Fetching comments for video BTqwJ0j0KqU...
#   Retrieved 234 comments.
# Fetching comments for video 40Lu63wEY4E...
#   Retrieved 14 comments.
# Fetching comments for video rIhlkIXGIYs...
#   Retrieved 190 comments.
# Fetching comments for video utvW2hsMnto...
#   Retrieved 284 comments.
# Fetching comments for video sx23iTTLfjw...
#   Retrieved 228 comments.
# Fetching comments for video YXTWovLjQU8...
#   Retrieved 9 comments.
# Fetching comments for video 2m001fZeGsg...
#   Retrieved 20 comments.
# Fetching comments for video frYExXiRH6A...
#   Retrieved 180 comments.
# Fetching comments for video KDJiXwhkotw...
#   Retrieved 10 comments.
# Fetching comments for video FClVNnUbhgs...
#   Retrieved 4 comments.
# Fetching comments for video 1bFSIE_GbDY...
#   Retrieved 4 comments.
# Fetching comments for video LB4h2QtCcnY...
#   Retrieved 69 comments.
# Fetching comments for video FBLnBSn0VFU...
#   Retrieved 59 comments.
# Fetching comments for video liKMVwazLws...
#   Retrieved 67 comments.
# Fetching comments for video K4GjXIZ-jtY...
#   Retrieved 7 comments.
# Fetching comments for video sEICavGQZUY...
#   Retrieved 17 comments.
# Fetching comments for video YCW7zoA9YOU...
#   Retrieved 1 comments.
# Fetching comments for video GDPIgCMrJYc...
#   Retrieved 42 comments.
# Fetching comments for video lznmVidRznw...
#   Retrieved 70 comments.
# Fetching comments for video x6SFWzYvUh4...
#   Retrieved 20 comments.
# Fetching comments for video BahSq8CfDbA...
#   Retrieved 169 comments.
# Fetching comments for video u_hQaRFQBwA...
#   Retrieved 7 comments.
# Fetching comments for video KKN0sGetyZ4...
#   Retrieved 456 comments.
# Fetching comments for video sZsDkcB20hk...
#   Retrieved 28 comments.
# Fetching comments for video ke27ouQgdgQ...
#   Retrieved 596 comments.
# Fetching comments for video THb7r5QkrKc...
#   Retrieved 31 comments.
# Fetching comments for video R7vd-pPJZbc...
#   Retrieved 224 comments.
# Fetching comments for video DkwFY3430RM...
#   Retrieved 17 comments.
# Fetching comments for video -jiGpL14bTo...
#   Retrieved 44 comments.
# Fetching comments for video Etvm-YdX_GQ...
#   Retrieved 19 comments.
# Fetching comments for video _HlO40LSe3o...
#   Retrieved 113 comments.
# Fetching comments for video tXy5nE-N7IU...
#   Retrieved 570 comments.
# Fetching comments for video JADu8EVaeYg...
#   Retrieved 1 comments.
# Fetching comments for video 08O81kxTXc8...
#   Retrieved 13 comments.
# Fetching comments for video 01DHv5oEaVM...
#   Retrieved 38 comments.
# Fetching comments for video Jx_TSClTXCc...
#   Retrieved 294 comments.
# Fetching comments for video T_dfgAc1M54...
#   Retrieved 35 comments.
# Fetching comments for video ApHvyiix5_w...
#   Retrieved 4 comments.
# Fetching comments for video sTwws4r6o1I...
#   Retrieved 17 comments.
# Fetching comments for video LSy_lYm6bRY...
#   Retrieved 54 comments.
# Fetching comments for video Plzx3ZRhLMY...
#   Retrieved 676 comments.
# Fetching comments for video vcy993HcvV0...
#   Retrieved 12 comments.
# Fetching comments for video QNnx2QLin-c...
#   Retrieved 2 comments.
# Fetching comments for video 5EfNFPexGsw...
#   Retrieved 45 comments.
# Fetching comments for video EOjg0T0ylE0...
#   Retrieved 14 comments.
# Fetching comments for video DPMHZEqO9jY...
#   Retrieved 60 comments.
# Fetching comments for video psgUMjjr6IA...
#   Retrieved 2 comments.
# Fetching comments for video NkUXEoeyMmA...
#   Retrieved 2 comments.
# Fetching comments for video TlauY3C5HjE...
#   Retrieved 42 comments.
# Fetching comments for video iS4Szs2uf5c...
#   Retrieved 179 comments.
# Fetching comments for video Kx29R6pEBd8...
#   Retrieved 559 comments.
# Fetching comments for video khDk8C2Uus0...
#   Retrieved 9 comments.
# Fetching comments for video je-APC2k1P4...
#   Retrieved 60 comments.
# Fetching comments for video 0tOqiMOajHk...
#   Retrieved 52 comments.
# Fetching comments for video f1tWxYts-eE...
#   Retrieved 193 comments.
# Fetching comments for video FJZlMPP-uWY...
#   Retrieved 46 comments.
# Fetching comments for video yGjtddhOnFU...
#   Retrieved 11 comments.
# Fetching comments for video 5M7OP6Ankjo...
#   Retrieved 19 comments.
# Fetching comments for video M0IZZcH8W-I...
#   Retrieved 9 comments.
# Fetching comments for video z5inaL1iXK4...
#   Retrieved 968 comments.
# Fetching comments for video -V4DXHtWum4...
#   Retrieved 23 comments.
# Fetching comments for video EQWvKXK0L9c...
#   Retrieved 45 comments.
# Fetching comments for video Dou45-GJqT4...
#   Retrieved 18 comments.
# Fetching comments for video WN1uhdBkCfc...
#   Retrieved 4 comments.
# Fetching comments for video _52haW01hZk...
#   Retrieved 30 comments.
# Fetching comments for video nNXYhPITpDg...
#   Retrieved 52 comments.
# Fetching comments for video yToOwcBVx2k...
#   Retrieved 4 comments.
# Fetching comments for video jnnNK3i7O5c...
#   Retrieved 21 comments.
# Fetching comments for video HnCH7npI6nY...
#   Retrieved 13 comments.
# Fetching comments for video vRH_qfWaTgI...
#   Retrieved 78 comments.
# Fetching comments for video YHsNfiQU2C0...
#   Retrieved 0 comments.
# Fetching comments for video 1hDDct6uw3k...
#   Retrieved 1 comments.
# Fetching comments for video YvlMxHcnv0c...
#   Retrieved 3 comments.
# Fetching comments for video vFWPl0vM2vY...
#   Retrieved 236 comments.
# Fetching comments for video whrMlMHnQz8...
#   Retrieved 160 comments.
# Fetching comments for video 7PSQTaltElE...
#   Retrieved 3 comments.
# Fetching comments for video 9-pM2jo2gS4...
#   Retrieved 49 comments.
# Fetching comments for video B1ku8eW6HgE...
#   Retrieved 82 comments.
# Fetching comments for video kF3qaBotFJw...
#   Retrieved 10 comments.
# Fetching comments for video vz_6kIwMvN0...
#   Retrieved 15 comments.
# Fetching comments for video Iph9vGGsx8c...
#   Retrieved 778 comments.
# Fetching comments for video g6edytZ64yo...
#   Retrieved 366 comments.
# Fetching comments for video d57k36rMn6M...
#   Retrieved 905 comments.
# Fetching comments for video 6m3dF1p_z2o...
#   Retrieved 8 comments.
# Fetching comments for video QGLhTnD83VE...
#   Retrieved 39 comments.
# Fetching comments for video lfHddUIWozk...
#   Retrieved 611 comments.
# Fetching comments for video RDt5Hyh1hIM...
#   Retrieved 4 comments.
# Fetching comments for video XYpnVXXvQbo...
#   Retrieved 144 comments.
# Fetching comments for video _0WOcD55Vac...
#   Retrieved 80 comments.
# Fetching comments for video kyHbMZ9au08...
#   Retrieved 1 comments.
# Fetching comments for video -cXQh9T2oJM...
#   Retrieved 22 comments.
# Fetching comments for video wKPkhxPo69s...
#   Retrieved 128 comments.
# Fetching comments for video Re0ZwQtgDYo...
#   Retrieved 3 comments.
# Fetching comments for video CdBKUwFOG94...
#   Retrieved 509 comments.
# Fetching comments for video rjmeICXen4w...
#   Retrieved 23 comments.
# Fetching comments for video bH4arS6Q-so...
#   Retrieved 199 comments.
# Fetching comments for video XnxhMedK-EQ...
#   Retrieved 16 comments.
# Fetching comments for video hygV-S92oqw...
#   Retrieved 90 comments.
# Fetching comments for video UR4AwKBOVPQ...
#   Retrieved 126 comments.
# Fetching comments for video hW7H8t6-wt0...
#   Retrieved 739 comments.
# Fetching comments for video sBKXq6ZJMOo...
#   Retrieved 375 comments.
# Fetching comments for video D0ZYpsb9qtE...
#   Retrieved 86 comments.
# Fetching comments for video CW8YnNoHKJM...
#   Retrieved 259 comments.
# Fetching comments for video kR6_LRUgrzw...
#   Retrieved 12 comments.
# Fetching comments for video K1SHDRnT50o...
#   Retrieved 118 comments.
# Fetching comments for video kkR3eaBDD50...
#   Retrieved 38 comments.
# Fetching comments for video JQ1fSNqJmIE...
#   Retrieved 139 comments.
# Fetching comments for video 02_9ma7Ueg0...
#   Retrieved 99 comments.
# Fetching comments for video yp_Cad7qFxU...
#   Retrieved 216 comments.
# Fetching comments for video otqzHlPYjVo...
#   Retrieved 3 comments.
# Fetching comments for video 6TdHr6ryu_E...
#   Retrieved 19 comments.
# Fetching comments for video 8Os1gZ5J9IA...
#   Retrieved 17 comments.
# Fetching comments for video hAtPswR8Bn4...
#   Retrieved 51 comments.
# Fetching comments for video VwcF3dEv3XY...
#   Retrieved 192 comments.
# Fetching comments for video OUC8FdwxRvg...
#   Retrieved 850 comments.
# Fetching comments for video U8aijc7ke34...
#   Retrieved 9 comments.
# Fetching comments for video nHNqgPKkNFA...
#   Retrieved 29 comments.
# Fetching comments for video e1caqFOS2i0...
#   Retrieved 148 comments.
# Fetching comments for video qD7fCj0Vwak...
#   Retrieved 4 comments.
# Fetching comments for video ZbRgUMwjVbA...
#   Retrieved 21 comments.
# Fetching comments for video KNu27HbVMjg...
#   Retrieved 29 comments.
# Fetching comments for video QG0Lso4sZa4...
#   Retrieved 97 comments.
# Fetching comments for video qnLh7ZVf3qU...
#   Retrieved 16 comments.
# Fetching comments for video 25IQHpVuE14...
#   Retrieved 9 comments.
# Fetching comments for video xSoUd24ejns...
#   Retrieved 294 comments.
# Fetching comments for video PBk1pk0EU5E...
#   Retrieved 29 comments.
# Fetching comments for video ms-wNzbiC0M...
#   Retrieved 11 comments.
# Fetching comments for video Sh7twwYVrfc...
#   Retrieved 978 comments.
# Fetching comments for video gzIrXhT-8XY...
#   Retrieved 39 comments.
# Fetching comments for video -pIj4UZPnIg...
#   Retrieved 279 comments.
# Fetching comments for video UaTFoPSm9zM...
#   Retrieved 172 comments.
# Fetching comments for video bSQYDsRL3iA...
#   Retrieved 109 comments.
# Fetching comments for video QGQ1eVr5qPQ...
#   Retrieved 186 comments.
# Fetching comments for video tWh-4FIz438...
#   Retrieved 37 comments.
# Fetching comments for video mSQJO5r8Bew...
#   Retrieved 34 comments.
# Fetching comments for video xJ_JJIjgKyk...
#   Retrieved 48 comments.
# Fetching comments for video i-9wgFJuXM0...
#   Retrieved 84 comments.
# Fetching comments for video Zg_GkdaDjWc...
#   Retrieved 27 comments.
# Fetching comments for video r0EjIihhCg4...
#   Retrieved 1154 comments.
# Fetching comments for video VUXPODsKF3g...
#   Retrieved 54 comments.
# Fetching comments for video LKHza9tOGvk...
#   Retrieved 77 comments.
# Fetching comments for video _lrJvDSlxqI...
#   Retrieved 4 comments.
# Fetching comments for video ZEB-vA5R54I...
#   Retrieved 86 comments.
# Fetching comments for video Ikatd2eXks8...
#   Retrieved 1342 comments.
# Fetching comments for video 45iv11PeDBA...
#   Retrieved 693 comments.
# Fetching comments for video jWUzJ4QJ6cM...
#   Retrieved 113 comments.
# Fetching comments for video Gx3c61mGeck...
#   Retrieved 448 comments.
# Fetching comments for video K7kEHiZNF2s...
#   Retrieved 145 comments.
# Fetching comments for video NV_TCiIrip8...
#   Retrieved 355 comments.
# Fetching comments for video tFbcfxdArA0...
#   Retrieved 8 comments.
# Fetching comments for video X-_vk4tdKOY...
#   Retrieved 37 comments.
# Fetching comments for video zphdf-ypwf4...
#   Retrieved 200 comments.
# Fetching comments for video 3QN_Wg8swGM...
#   Retrieved 174 comments.
# Fetching comments for video IDPfRn-nY8s...
#   Retrieved 16 comments.
# Fetching comments for video KAkXvypdys8...
#   Retrieved 143 comments.
# Fetching comments for video 9Eh89DTA-uQ...
#   Retrieved 112 comments.
# Fetching comments for video MYUUdlqrLns...
#   Retrieved 117 comments.
# Fetching comments for video Ca6_8kTGZXQ...
#   Retrieved 12 comments.
# Fetching comments for video kq6avtTMTWQ...
#   Retrieved 413 comments.
# Fetching comments for video 7mFP6qv8710...
#   Retrieved 42 comments.
# Fetching comments for video XOBfPAMbydU...
#   Retrieved 28 comments.
# Fetching comments for video zE2E5d5NpCo...
#   Retrieved 133 comments.
# Fetching comments for video 23dblkoOVkg...
#   Retrieved 77 comments.
# Fetching comments for video oohhX_f16m0...
#   Retrieved 4 comments.
# Fetching comments for video xZ9W0nfRW2U...
#   Retrieved 77 comments.
# Fetching comments for video gLOpv3H6TiY...
#   Retrieved 82 comments.
# Fetching comments for video ZQ9afPir6E0...
#   Retrieved 6 comments.
# Fetching comments for video d8488olbU5M...
#   Retrieved 6 comments.
# Fetching comments for video m8LrKYJ56x4...
#   Retrieved 692 comments.
# Fetching comments for video UJJFuo4WtWI...
#   Retrieved 5 comments.
# Fetching comments for video FibSL5v5tWI...
#   Retrieved 160 comments.
# Fetching comments for video _w0codJ9288...
#   Retrieved 1 comments.
# Fetching comments for video mWscaJdDxEU...
#   Retrieved 78 comments.
# Fetching comments for video XJQ8rEFwOAw...
#   Retrieved 12 comments.
# Fetching comments for video t7c5rdW1xKU...
#   Retrieved 20 comments.
# Fetching comments for video bcFyicwcR6Y...
#   Retrieved 80 comments.
# Fetching comments for video Sp1PfX9GN9c...
#   Retrieved 169 comments.
# Fetching comments for video XhaNoZwLwjc...
#   Retrieved 7 comments.
# Fetching comments for video 4xm7vC2OKVg...
#   Retrieved 11 comments.
# Fetching comments for video MtUwQHHBjaU...
#   Retrieved 3 comments.
# Fetching comments for video 14B5nSNkdyA...
#   Retrieved 66 comments.
# Fetching comments for video 32kLBIeXa5k...
#   Retrieved 52 comments.
# Fetching comments for video Cp0PEddS0QU...
#   Retrieved 11 comments.
# Fetching comments for video nMUaOky7548...
#   Retrieved 19 comments.
# Fetching comments for video _2apL1_HqK4...
#   Retrieved 9 comments.
# Fetching comments for video 8hP0DmId9Dc...
#   Retrieved 87 comments.
# Fetching comments for video aRiqm_KyitI...
#   Retrieved 8 comments.
# Fetching comments for video WTf4ncWyBqI...
#   Retrieved 479 comments.
# Fetching comments for video X1_3v4PFPdY...
#   Retrieved 527 comments.
# Fetching comments for video 6uXtq17Zh_M...
#   Retrieved 1688 comments.
# Fetching comments for video BelhFQHlCpA...
#   Retrieved 1622 comments.
# Fetching comments for video 7_sS3b3K1Ik...
#   Retrieved 312 comments.
# Fetching comments for video Yt212ogizvY...
#   Retrieved 45 comments.
# Fetching comments for video E9mtSKEN7LQ...
#   Retrieved 180 comments.
# Fetching comments for video NXKaCioC6yM...
#   Retrieved 258 comments.
# Fetching comments for video 5mveRLA0EOA...
#   Retrieved 389 comments.
# Fetching comments for video 59mXMTeNfa0...
#   Retrieved 388 comments.
# Fetching comments for video oCfPSyufbW4...
#   Retrieved 236 comments.
# Fetching comments for video bv8AcJ2QR9Q...
#   Retrieved 1093 comments.
# Fetching comments for video 3kXjh36Y824...
#   Retrieved 991 comments.
# Fetching comments for video _6-X6vByw1Q...
#   Retrieved 1886 comments.
# Fetching comments for video Kxaoq5a4lDw...
#   Retrieved 81 comments.
# Fetching comments for video 1B1odDhGaHE...
#   Retrieved 130 comments.
# Fetching comments for video cas8q7shln0...
#   Retrieved 281 comments.
# Fetching comments for video Cf_VBon0cuc...
#   Retrieved 273 comments.
# Fetching comments for video 2j4ODlX-ORg...
#   Retrieved 174 comments.
# Fetching comments for video T47sfB1gheo...
#   Retrieved 84 comments.
# Fetching comments for video t7jQbgXlZT8...
#   Retrieved 459 comments.
# Fetching comments for video cpWjW2GAmYY...
#   Retrieved 499 comments.
# Fetching comments for video 0XSqfwQNETc...
#   Retrieved 444 comments.
# Fetching comments for video NqO1ktjWUws...
#   Retrieved 305 comments.
# Fetching comments for video rrrvT1314LY...
#   Retrieved 545 comments.
# Fetching comments for video b5lA6F9Dye4...
#   Retrieved 87 comments.
# Fetching comments for video _ILmOwbP5ic...
#   Retrieved 184 comments.
# Fetching comments for video LMpeHvKGBXE...
#   Retrieved 312 comments.
# Fetching comments for video IJbnoSo7WRI...
#   Retrieved 1043 comments.
# Fetching comments for video BERKsnrO0ms...
#   Retrieved 219 comments.
# Fetching comments for video Sq809Qp3cHw...
#   Retrieved 2199 comments.
# Fetching comments for video 11QoZzCoG5k...
#   Retrieved 1078 comments.
# Fetching comments for video roe3abcIp7g...
#   Retrieved 859 comments.
# Fetching comments for video i-9dPSFFUto...
#   Retrieved 55 comments.
# Fetching comments for video 0CE9DhGayY0...
#   Retrieved 1338 comments.
# Fetching comments for video HQRfKb9-k5Q...
#   Retrieved 433 comments.
# Fetching comments for video H0RO2EwHfRY...
#   Retrieved 624 comments.
# Fetching comments for video yk2imdH3Veg...
#   Retrieved 522 comments.
# Fetching comments for video YbRmXqk35Hg...
#   Retrieved 413 comments.
# Fetching comments for video gl2ixCG1NzI...
#   Retrieved 3614 comments.
# Fetching comments for video _8DOYN43S60...
#   Retrieved 2156 comments.
# Fetching comments for video N0Lixu6T7aU...
#   Retrieved 922 comments.
# Fetching comments for video iatxkEyNqrQ...
#   Retrieved 295 comments.
# Fetching comments for video QHjGS8GrONw...
#   Retrieved 515 comments.
# Fetching comments for video _h29NkEk9rU...
#   Retrieved 36 comments.
# Fetching comments for video 3c037UehVz4...
#   Retrieved 383 comments.
# Fetching comments for video GEZ3pn0WtcY...
#   Retrieved 288 comments.
# Fetching comments for video aFutfJMMRe4...
#   Retrieved 319 comments.
# Fetching comments for video wQtMWThp8Ec...
#   Retrieved 856 comments.
# Fetching comments for video CUBw1qTcumY...
#   Retrieved 1016 comments.
# Fetching comments for video m8QGKqNCbYM...
#   Retrieved 1979 comments.
# Fetching comments for video SuH2eChTmn0...
#   Retrieved 163 comments.
# Fetching comments for video NQxMjJ4RZ-Y...
#   Retrieved 566 comments.
# Fetching comments for video vRxeaVy3Ud8...
#   Retrieved 213 comments.
# Fetching comments for video 0LtgMAzQ9JQ...
#   Retrieved 673 comments.
# Fetching comments for video nTbR7aeJDB4...
#   Retrieved 1674 comments.
# Fetching comments for video L5o0_x1D5sc...
#   Retrieved 445 comments.
# Fetching comments for video 02iFjkpLnHA...
#   Retrieved 439 comments.
# Fetching comments for video sJqc9EQOrHE...
#   Retrieved 186 comments.
# Fetching comments for video qJdPPlWyyAw...
#   Retrieved 258 comments.
# Fetching comments for video gvzPN6zF12M...
#   Retrieved 171 comments.
# Fetching comments for video cOoBWnImFx8...
#   Retrieved 124 comments.
# Fetching comments for video WfhGnqt0ZAY...
#   Retrieved 172 comments.
# Fetching comments for video 7ysVK-Rc-7M...
#   Retrieved 1031 comments.
# Fetching comments for video yNt590k2wyM...
#   Retrieved 370 comments.
# Fetching comments for video dB54lCt64Mk...
#   Retrieved 1028 comments.
# Fetching comments for video PfJq3Klt-3s...
#   Retrieved 517 comments.
# Fetching comments for video uMRvabWBI8M...
#   Retrieved 3913 comments.
# Fetching comments for video 3ZarHb4qhYQ...
#   Retrieved 133 comments.
# Fetching comments for video s5jjfW34ycs...
#   Retrieved 220 comments.
# Fetching comments for video Ybaj_DBp_Gg...
#   Retrieved 66 comments.
# Fetching comments for video MgejAnALMWA...
#   Retrieved 221 comments.
# Fetching comments for video tGWF1Dius8c...
#   Retrieved 227 comments.
# Fetching comments for video efZisZxLErs...
#   Retrieved 3056 comments.
# Fetching comments for video oJciRpB5rYg...
#   Retrieved 447 comments.
# Fetching comments for video JVkDfF5l35A...
#   Retrieved 110 comments.
# Fetching comments for video HoYu5ZTu64A...
#   Retrieved 222 comments.
# Fetching comments for video mHWRkt8F1X4...
#   Retrieved 230 comments.
# Fetching comments for video g7tPPDDSTu8...
#   Retrieved 1159 comments.
# Fetching comments for video O7Xf__bcbVg...
#   Retrieved 1718 comments.
# Fetching comments for video yGdauC2Q2vY...
#   Retrieved 146 comments.
# Fetching comments for video yzAGh7TI1Xg...
#   Retrieved 103 comments.
# Fetching comments for video Cxw41dEVq7M...
#   Retrieved 57 comments.
# Fetching comments for video 7wI2TivMnbg...
#   Retrieved 2934 comments.
# Fetching comments for video uZZRJnFYVvk...
#   Retrieved 337 comments.
# Fetching comments for video UvgVJGMwzeA...
#   Retrieved 472 comments.
# Fetching comments for video arr9A-DkQJc...
#   Retrieved 51 comments.
# Fetching comments for video S38fVuD2EXM...
#   Retrieved 243 comments.
# Fetching comments for video P7wpivM-OjQ...
#   Retrieved 1232 comments.
# Fetching comments for video E35RyFuDOLA...
#   Retrieved 167 comments.
# Fetching comments for video pj0IJLzKUdw...
#   Retrieved 5564 comments.
# Fetching comments for video GN9C0AWODGE...
#   Retrieved 201 comments.
# Fetching comments for video 0JU2ONszCHI...
#   Retrieved 129 comments.
# Fetching comments for video mG9ZqW_jnHw...
#   Retrieved 410 comments.
# Fetching comments for video ruqf_0xXR-o...
#   Retrieved 820 comments.
# Fetching comments for video BCN8-T40ElA...
#   Retrieved 69 comments.
# Fetching comments for video IpsDUY6Ugsw...
#   Retrieved 1958 comments.
# Fetching comments for video xSgm3TwQbTA...
#   Retrieved 547 comments.
# Fetching comments for video -vA4ZtpPS8Y...
#   Retrieved 4640 comments.
# Fetching comments for video LvTf_-0prOQ...
#   Retrieved 1598 comments.
# Fetching comments for video rUu_HQkEilc...
#   Retrieved 219 comments.
# Fetching comments for video Sd53GaQWm5o...
#   Retrieved 343 comments.
# Fetching comments for video 9-mpWzKlbXk...
#   Retrieved 1 comments.
# Fetching comments for video lSOlJ5eek-M...
#   Retrieved 0 comments.
# Fetching comments for video YEuHI2tK5no...
#   Retrieved 1 comments.
# Fetching comments for video 89Y-ELEzsO4...
#   Retrieved 154 comments.
# Fetching comments for video u7oWRyYLbzE...
#   Retrieved 13 comments.
# Fetching comments for video RAiDUa264JQ...
#   Retrieved 5 comments.
# Fetching comments for video WdUavvhRTcg...
#   Retrieved 3 comments.
# Fetching comments for video e7lh0pMmwoo...
#   Retrieved 3 comments.
# Fetching comments for video 98U_GHDvKcI...
#   Retrieved 8 comments.
# Fetching comments for video Djf_Mmg3_BY...
#   Retrieved 3 comments.
# Fetching comments for video 779w_RDtxz0...
#   Retrieved 0 comments.
# Fetching comments for video 4jLWD8E7ZlM...
#   Retrieved 12 comments.
# Fetching comments for video -6KK6S8uQ9U...
#   Retrieved 295 comments.
# Fetching comments for video tm_qtbYaGsQ...
#   Retrieved 0 comments.
# Fetching comments for video dTCraO9xx-o...
#   Retrieved 18 comments.
# Fetching comments for video _7bG5obN6bE...
#   Retrieved 1 comments.
# Fetching comments for video SEfWOqPJX8E...
#   Retrieved 1 comments.
# Fetching comments for video fcF5IDEvai0...
#   Retrieved 2 comments.
# Fetching comments for video Ijxy3yELpCU...
#   Retrieved 7 comments.
# Fetching comments for video 41PXBo-uWmI...
#   Retrieved 3 comments.
# Fetching comments for video MzgX8mnUPvQ...
#   Retrieved 1 comments.
# Fetching comments for video ogPRYv22oZ8...
#   Retrieved 10 comments.
# Fetching comments for video TWFk1VS6G7s...
#   Retrieved 1 comments.
# Fetching comments for video 0TWKWdvXtug...
#   Retrieved 0 comments.
# Fetching comments for video zTcsMa_64aQ...
#   Retrieved 2 comments.
# Fetching comments for video mWDDeVuwa1Q...
#   Retrieved 104 comments.
# Fetching comments for video P2xh1hcyAP8...
#   Retrieved 0 comments.
# Fetching comments for video Fp0rP-obCwk...
#   Retrieved 4 comments.
# Fetching comments for video 4J5Z_vwN5zw...
#   Retrieved 79 comments.
# Fetching comments for video h7Xin6OEnvo...
#   Retrieved 5 comments.
# Fetching comments for video OYbXlduEAQ4...
#   Retrieved 5 comments.
# Fetching comments for video mbpgkTpljFQ...
#   Retrieved 7 comments.
# Fetching comments for video xAJVpEsMluc...
#   Retrieved 86 comments.
# Fetching comments for video 4HBWkvjtm20...
#   Retrieved 5 comments.
# Fetching comments for video l0Fvf0XEJQ8...
#   Retrieved 6 comments.
# Fetching comments for video YmAwKmlsiY0...
#   Retrieved 4 comments.
# Fetching comments for video wKv74K4bq1E...
#   Retrieved 2 comments.
# Fetching comments for video VCtB7h-L17g...
#   Retrieved 1 comments.
# Fetching comments for video hTuGGVqFTnE...
#   Retrieved 57 comments.
# Fetching comments for video X5Zl3SDeD10...
#   Retrieved 74 comments.
# Fetching comments for video ZuMylycRzrE...
#   Retrieved 17 comments.
# Fetching comments for video EshgRCBChrk...
#   Retrieved 361 comments.
# Fetching comments for video 8q43Q2bimEg...
#   Retrieved 3 comments.
# Fetching comments for video lOqF7hSKo28...
#   Retrieved 9 comments.
# Fetching comments for video -S_pbLbxQ6k...
#   Retrieved 2 comments.
# Fetching comments for video b-M4XuqTr9A...
#   Retrieved 65 comments.
# Fetching comments for video cdIfQzAj7PE...
#   Retrieved 6 comments.
# Fetching comments for video aXdckFcFIx0...
#   Retrieved 1 comments.
# Fetching comments for video 6vC4jc7R6X0...
#   Retrieved 35 comments.
# Fetching comments for video A3FNj9Q05mI...
#   Retrieved 3 comments.
# Fetching comments for video wV2K9bZ8pdU...
#   Retrieved 1 comments.
# Fetching comments for video OTycUxKi_Tg...
#   Retrieved 63 comments.
# Fetching comments for video _Z1sjLDRxi8...
#   Retrieved 8 comments.
# Fetching comments for video xcB3ag0rcX4...
#   Retrieved 29 comments.
# Fetching comments for video JNJN_jY8sDw...
#   Retrieved 7 comments.
# Fetching comments for video 2UCkql9aibE...
#   Retrieved 519 comments.
# Fetching comments for video bmXF465Nn7U...
#   Retrieved 7 comments.
# Fetching comments for video nb1WJIGx1kA...
#   Retrieved 100 comments.
# Fetching comments for video n1Fylp_82dw...
#   Retrieved 153 comments.
# Fetching comments for video WR-CDomfZs4...
#   Retrieved 183 comments.
# Fetching comments for video snYkY-n2Uls...
#   Retrieved 1032 comments.
# Fetching comments for video Bb4dPM29QJ0...
#   Retrieved 901 comments.
# Fetching comments for video NTYY1-D0M1Q...
#   Retrieved 18 comments.
# Fetching comments for video pJa081wdGcc...
#   Retrieved 468 comments.
# Fetching comments for video XiZJLbL58Xk...
#   Retrieved 446 comments.
# Fetching comments for video 0fsnaEkHj2E...
#   Retrieved 18 comments.
# Fetching comments for video eeXKnl_dwCs...
#   Retrieved 22 comments.
# Fetching comments for video 5SEDJruyQQE...
#   Retrieved 10 comments.
# Fetching comments for video pi9ICtqdLFY...
#   Retrieved 0 comments.
# Fetching comments for video KA_SUYrtMg0...
#   Retrieved 3 comments.
# Fetching comments for video 0tmSrssxQrs...
#   Retrieved 3 comments.
# Fetching comments for video eRTd1MSaOQ8...
#   Retrieved 11 comments.
# Fetching comments for video GwxTer8IWFM...
#   Retrieved 6 comments.
# Fetching comments for video N9UCnsysaG0...
#   Retrieved 152 comments.
# Fetching comments for video se7lGAEwdOw...
#   Retrieved 4 comments.
# Fetching comments for video WmZohy05bU8...
#   Retrieved 0 comments.
# Fetching comments for video Njn4hyuwL7A...
#   Retrieved 3 comments.
# Fetching comments for video AL8OC-dgJ4M...
#   Retrieved 0 comments.
# Fetching comments for video 6zZzIoHig4M...
#   Retrieved 5 comments.
# Fetching comments for video FEf8pQgVbZ0...
#   Retrieved 73 comments.
# Fetching comments for video x1wzqvEt2x4...
#   Retrieved 38 comments.
# Fetching comments for video 2Lg7gsldLcg...
#   Retrieved 2 comments.
# Fetching comments for video UezIRkq53J8...
#   Retrieved 0 comments.
# Fetching comments for video eEv8pTxaSEA...
#   Retrieved 13 comments.
# Fetching comments for video XdsPNskNVLU...
#   Retrieved 2 comments.
# Fetching comments for video UyCqH0ltZRQ...
#   Retrieved 7 comments.
# Fetching comments for video L6Kh1mKTEIw...
#   Retrieved 1 comments.
# Fetching comments for video TPY6e19avtQ...
#   Retrieved 4 comments.
# Fetching comments for video hC90--x98xQ...
#   Retrieved 3 comments.
# Fetching comments for video IIpS3gLz_wk...
#   Retrieved 24 comments.
# Fetching comments for video I8AmporFkls...
#   Retrieved 259 comments.
# Fetching comments for video Ya-wkeGxpT4...
#   Retrieved 37 comments.
# Fetching comments for video OzU3Bd7RCVg...
#   Retrieved 0 comments.
# Fetching comments for video iWiSoLA86ns...
#   Retrieved 3 comments.
# Fetching comments for video rLqUq0WBIOU...
#   Retrieved 0 comments.
# Fetching comments for video rMQ66MsZ6w8...
#   Retrieved 4 comments.
# Fetching comments for video qmbUBFaumrk...
#   Retrieved 71 comments.
# Fetching comments for video OQ152HlpmZg...
#   Retrieved 25 comments.
# Fetching comments for video De2dHWLcCag...
#   Retrieved 11 comments.
# Fetching comments for video kAM3pxu7zwU...
#   Retrieved 18 comments.
# Fetching comments for video NIHU7Y8-8k4...
#   Retrieved 294 comments.
# Fetching comments for video bR_eODwlBmY...
#   Retrieved 100 comments.
# Fetching comments for video ABn4osxkek4...
#   Retrieved 26 comments.
# Fetching comments for video W2FM1vmXdd8...
#   Retrieved 739 comments.
# Fetching comments for video skqnmoV7CzE...
#   Retrieved 26 comments.
# Fetching comments for video f3c4mQty_so...
#   Retrieved 4989 comments.
# Fetching comments for video frWRIfj6b5Q...
#   Retrieved 935 comments.
# Fetching comments for video dZ6xpF_HljU...
#   Retrieved 85 comments.
# Fetching comments for video JuGpYqPI60k...
#   Retrieved 350 comments.
# Fetching comments for video Z2TXNPB81vo...
#   Retrieved 2048 comments.
# Fetching comments for video HkT8mNd_ez0...
#   Retrieved 34 comments.
# Fetching comments for video SASDkIQjouI...
#   Retrieved 781 comments.
# Fetching comments for video gTRYIT9ypbs...
#   Retrieved 55 comments.
# Fetching comments for video nr3RNRfxnl4...
#   Retrieved 120 comments.
# Fetching comments for video hSRrxK9H3q0...
#   Retrieved 378 comments.
# Fetching comments for video 3yaCEtOMWTo...
#   Retrieved 69 comments.
# Fetching comments for video Lxo6Xr8u6Zk...
#   Retrieved 2700 comments.
# Fetching comments for video xll6ydqwutw...
#   Retrieved 3 comments.
# Fetching comments for video xd8WrFCZyU8...
#   Retrieved 41 comments.
# Fetching comments for video ZeijhIKyq-0...
#   Retrieved 31 comments.
# Fetching comments for video Z67kl1LOKtc...
#   Retrieved 415 comments.
# Fetching comments for video TUNzxBWZJkQ...
#   Retrieved 566 comments.
# Fetching comments for video _OXc19uHadE...
#   Retrieved 12 comments.
# Fetching comments for video cnV4JkTGUjo...
#   Retrieved 400 comments.
# Fetching comments for video VIEHv1mvkP0...
#   Retrieved 31 comments.
# Fetching comments for video OzjYNVJwqH0...
#   Retrieved 331 comments.
# Fetching comments for video TuwSLP0zplo...
#   Retrieved 51 comments.
# Fetching comments for video Jaqlce0PBHo...
#   Retrieved 67 comments.
# Fetching comments for video rmf2k48m70c...
#   Retrieved 30 comments.
# Fetching comments for video OmKncT3Zdoo...
#   Retrieved 583 comments.
# Fetching comments for video Z4RbazXKoTA...
#   Retrieved 46 comments.
# Fetching comments for video NmbxQaxKuRo...
#   Retrieved 22 comments.
# Fetching comments for video uVSeMXncHZ0...
#   Retrieved 774 comments.
# Fetching comments for video 6Vb0uIqDDYs...
#   Retrieved 15 comments.
# Fetching comments for video G3W3qH-Wp44...
#   Retrieved 340 comments.
# Fetching comments for video M4hlJ07m_2I...
#   Retrieved 72 comments.
# Fetching comments for video Yt8wZjz7th8...
#   Retrieved 110 comments.
# Fetching comments for video NE1CJsYypPI...
#   Retrieved 104 comments.
# Fetching comments for video I4AGc3kgoko...
#   Retrieved 92 comments.
# Fetching comments for video VjZ6jJihVuU...
#   Retrieved 71 comments.
# Fetching comments for video ib7_VCWDdsE...
#   Retrieved 291 comments.
# Fetching comments for video 7rw2UZQz-hE...
#   Retrieved 98 comments.
# Fetching comments for video KjZF2K6x_T8...
#   Retrieved 257 comments.
# Fetching comments for video a-dJtdMfcqI...
#   Retrieved 44 comments.
# Fetching comments for video eMONiy-zQak...
#   Retrieved 119 comments.
# Fetching comments for video M_Fs8NVFdE0...
#   Retrieved 22 comments.
# Fetching comments for video 8hJcBLNaQfE...
#   Retrieved 324 comments.
# Fetching comments for video 96ENijQ_cX0...
#   Retrieved 20 comments.
# Fetching comments for video tmh5uebG9yE...
#   Retrieved 82 comments.
# Fetching comments for video TDjoueNVKu4...
#   Retrieved 52 comments.
# Fetching comments for video 4NsQ-QzuobQ...
#   Retrieved 210 comments.
# Fetching comments for video ZjBuj-1Tf9o...
#   Retrieved 94 comments.
# Fetching comments for video rMpVkTJKWRE...
#   Retrieved 54 comments.
# Fetching comments for video KB8RWULtiQc...
#   Retrieved 765 comments.
# Fetching comments for video v68YC8eKKpI...
#   Retrieved 524 comments.
# Fetching comments for video GDMO-HWvH38...
#   Retrieved 1092 comments.
# Fetching comments for video Sj3w_Wa9_v8...
#   Retrieved 134 comments.
# Fetching comments for video onsEZNtGKCA...
#   Retrieved 794 comments.
# Fetching comments for video _HIMerYXud4...
#   Retrieved 27 comments.
# Fetching comments for video a7dlpdWl9gk...
#   Retrieved 153 comments.
# Fetching comments for video xLf1EneAyLQ...
#   Retrieved 2452 comments.
# Fetching comments for video lvqZp7djDNE...
#   Retrieved 790 comments.
# Fetching comments for video UbpF6DSX3Rw...
#   Retrieved 316 comments.
# Fetching comments for video KHZLJXZSXzw...
#   Retrieved 205 comments.
# Fetching comments for video Z76xp_xw60c...
#   Retrieved 40 comments.
# Fetching comments for video M_RhfwhLkVM...
#   Retrieved 32 comments.
# Fetching comments for video _UO6LCIAknw...
#   Retrieved 1570 comments.
# Fetching comments for video hG_6e9ExPnw...
#   Retrieved 3 comments.
# Fetching comments for video 1lwDi9XybuY...
#   Retrieved 32 comments.
# Fetching comments for video M27ph9iAOi0...
#   Retrieved 68 comments.
# Fetching comments for video wxbvfsQGxdM...
#   Retrieved 142 comments.
# Fetching comments for video uEMgmOldoNY...
#   Retrieved 1122 comments.
# Fetching comments for video 9jRO_VV9Qxo...
#   Retrieved 567 comments.
# Fetching comments for video 1NFJYgphON4...
#   Retrieved 153 comments.
# Fetching comments for video lAbRMWY5TAI...
#   Retrieved 21 comments.
# Fetching comments for video 6jDg_4r46is...
#   Retrieved 239 comments.
# Fetching comments for video RdG7AQ8h6BY...
#   Retrieved 199 comments.
# Fetching comments for video 1mjSqFDzKqg...
#   Retrieved 63 comments.
# Fetching comments for video kh-XjYct1UA...
#   Retrieved 44 comments.
# Fetching comments for video v-A5arC6wVQ...
#   Retrieved 124 comments.
# Fetching comments for video ZjjomhN9M_M...
#   Retrieved 215 comments.
# Fetching comments for video wnfiKm5T4rM...
#   Retrieved 37 comments.
# Fetching comments for video G5P2FjVAt4c...
#   Retrieved 48 comments.
# Fetching comments for video wLdpA3GaRQg...
#   Retrieved 28 comments.
# Fetching comments for video 2IGEzn0YMA0...
#   Retrieved 328 comments.
# Fetching comments for video Eyh2VQJqKzw...
#   Retrieved 300 comments.
# Fetching comments for video Jky2T7cYw1c...
#   Retrieved 44 comments.
# Fetching comments for video wAZ7gD8VFjI...
#   Retrieved 125 comments.
# Fetching comments for video C0MZtpEgqJY...
#   Retrieved 76 comments.
# Fetching comments for video rTNYTh345EE...
#   Retrieved 288 comments.
# Fetching comments for video BQ1lXIapoUk...
#   Retrieved 62 comments.
# Fetching comments for video OkttgMa5sZs...
#   Retrieved 200 comments.
# Fetching comments for video 02fbxkl0UgQ...
#   Retrieved 2413 comments.
# Fetching comments for video FNH4qpd5BjU...
#   Retrieved 481 comments.
# Fetching comments for video H_4BDe_MT-U...
#   Retrieved 223 comments.
# Fetching comments for video W2zrUc4HHxY...
#   Retrieved 243 comments.
# Fetching comments for video Ku-S_nFG60I...
#   Retrieved 489 comments.
# Fetching comments for video PihndyCu5xE...
#   Retrieved 156 comments.
# Fetching comments for video kKjztnwc2Gg...
#   Retrieved 18 comments.
# Fetching comments for video qV7xYnv6fl0...
#   Retrieved 110 comments.
# Fetching comments for video wKXYu3bx87k...
#   Retrieved 33 comments.
# Fetching comments for video JdJv3HUBv-Q...
#   Retrieved 108 comments.
# Fetching comments for video sTJHjfPLEpY...
#   Retrieved 2 comments.
# Fetching comments for video TFvKK8kRVCw...
#   Retrieved 171 comments.
# Fetching comments for video 7aVDnCpPx5U...
#   Retrieved 112 comments.
# Fetching comments for video H-Yxv-kBCXc...
#   Retrieved 70 comments.
# Fetching comments for video e5bXwlwnNQk...
#   Retrieved 6 comments.
# Fetching comments for video rgNuNldpT_k...
#   Retrieved 153 comments.
# Fetching comments for video MIt6GYlyg5A...
#   Retrieved 2923 comments.
# Fetching comments for video JmMZETLzkvA...
#   Retrieved 41 comments.
# Fetching comments for video 0-xOVcRrP5A...
#   Retrieved 72 comments.
# Fetching comments for video ant2-X9E3Y8...
#   Retrieved 14 comments.
# Fetching comments for video _PGt7UgPkKQ...
#   Retrieved 890 comments.
# Fetching comments for video JbKqNjja4u4...
#   Retrieved 27 comments.
# Fetching comments for video 3f4MiB5dpHM...
#   Retrieved 18 comments.
# Fetching comments for video 6a5l_hcUY6A...
#   Retrieved 133 comments.
# Fetching comments for video xt5zHOc_Zs8...
#   Retrieved 3020 comments.
# Fetching comments for video Jh_O9825yhA...
#   Retrieved 100 comments.
# Saved 293848 comments to october_video_comments.csv
